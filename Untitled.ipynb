# %%
import pandas as pd
a={
'Name':['Ghulam Abbas','Ali Ahmed','ibad khan'],
'Age':[22,23,22]
}
df=pd.dataframe(a)
print(df)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 a={
#       3 'Name':['Ghulam Abbas','Ali Ahmed','ibad khan'],
#       4 'Age':[22,23,22]
#       5 }
#       6 df=pd.dataframe(a)
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import numpy as np

# 1D Array
arr1 = np.array([1, 2, 3, 4, 5])
print("1D Array:", arr1)

# 2D Array (Matrix)
arr2 = np.array([[1, 2, 3], [4, 5, 6]])
print("2D Array:\n", arr2)

# 3D Array (Tensor)
arr3 = np.array([[[1, 2], [3, 4]], [[5, 6], [7, 8]]])
print("3D Array:\n", arr3)

# Generating an array with zeros
zeros_arr = np.zeros((3, 3))
print("Zeros Array:\n", zeros_arr)

# Generating an array with ones
ones_arr = np.ones((2, 4))
print("Ones Array:\n", ones_arr)

# Generating an array with a range of numbers
range_arr = np.arange(1, 11, 2)  # Start=1, Stop
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import numpy as np
#       3 # 1D Array
#       4 arr1 = np.array([1, 2, 3, 4, 5])
#
# ModuleNotFoundError: No module named 'numpy'
